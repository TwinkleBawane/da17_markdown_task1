# %% [markdown]
# EXAMPLES OF MARKDOWN
#
# 1.Heading
#
# # Title 1
# ## Title 2
# ### Title 3
# #### Title 4
# ##### Title 5
# ###### Title 6

# %% [markdown]
# 2. Text Formatting
#
# *Itlaic* or _Italic_
#
# **Bold** or __Bold__
#
# ***Bold and Italic***
#
# ~~strikethrough~~

# %% [markdown]
# 3.Lists
#
# (unordered)
# - First
# - Second
#  - second_a
# - Third

# %% [markdown]
# (ordered)
# 1. First
# 2. Second
#    1. A Of First
#    2. A of Second

# %% [markdown]
# 4. Links
#
# https://www.linkedin.com/feed/

# %% [markdown]
# 5.Image
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <video controls src="20250619-1120-45.1400831.mp4" title="Title"></video>

# %% [markdown]
# 6. Blockquote
#
# > This is a blockquote.
# >> Nested blockquote.

# %% [markdown]
# 7. Code
#
# Use `print()` to display output.

# %% [markdown]
# 8. Horizontal Line
#
# ------

# %% [markdown]
# 9. Tables
#
# | Name | Grade |
# |----- |-------|
# | Twinkle|-----|

# %% [markdown]
# 10. CheckBox
#
# - [x] Task 1 completed
# - [ ] Task 2 not completed
