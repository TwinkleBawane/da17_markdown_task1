# %% [markdown]
# # Examples of:

# %% [markdown]
# 1. Int

# %%
age = 25
print (f"the type of age is {type(age)} and the value of age is {age}")
# Out:
# the type of age is <class 'int'> and the value of age is 25

# %%
year = 2024
print(f"the type of year is {type(year)} and the value of the year is {year}")

temperature = -10
print(f"the type of temperature is {type(temperature)} and value of temperature is {temperature}")

score = 100
print(f"the type of score is {type(score)} and value of score is {score}")

quantity = 50
print(f"the type of quantity is {type(quantity)} and value of quantity is {quantity}")

heightCm = 175
print(f"the type of heightCm is {type(heightCm)} and value of heightCm is {heightCm}")

weightKg = 60
print(f"the type of weightKg is {type(weightKg)} and value of weightKg is {weightKg}")

studentsCount = 30
print(f"the type of studentsCount is {type(studentsCount)} and value of studentsCount is {studentsCount}")

buildings = 12
print(f"the type of buildings is {type(buildings)} and value of buildings is {buildings}")

pagesRead = 120
print(f"the type of pagesRead is {type(pagesRead)} and value of pagesRead is {pagesRead}")

marksMath = 88
print(f"the type of marksMath is {type(marksMath)} and value of marksMath is {marksMath}")

apples = 4
print(f"the type of apples is {type(apples)} and value of apples is {apples}")

oranges = 7
print(f"the type of oranges is {type(oranges)} and value of oranges is {oranges}")

siblingCount = 2
print(f"the type of siblingCount is {type(siblingCount)} and value of siblingCount is {siblingCount}")

distanceKm = 15
print(f"the type of distanceKm is {type(distanceKm)} and value of distanceKm is {distanceKm}")

birthDay = 11
print(f"the type of birthDay is {type(birthDay)} and value of birthDay is {birthDay}")

rank = 3
print(f"the type of rank is {type(rank)} and value of rank is {rank}")

totalVotes = 500
print(f"the type of totalVotes is {type(totalVotes)} and value of totalVotes is {totalVotes}")

carsInLot = 70
print(f"the type of carsInLot is {type(carsInLot)} and value of carsInLot is {carsInLot}")

booksOwned = 1000
print(f"the type of booksOwned is {type(booksOwned)} and value of booksOwned is {booksOwned}")

roomNumber = 404
print(f"the type of roomNumber is {type(roomNumber)} and value of roomNumber is {roomNumber}")

speedLimit = 60
print(f"the type of speedLimit is {type(speedLimit)} and value of speedLimit is {speedLimit}")

pendingTasks = 5
print(f"the type of pendingTasks is {type(pendingTasks)} and value of pendingTasks is {pendingTasks}")

houseNumber = 23
print(f"the type of houseNumber is {type(houseNumber)} and value of houseNumber is {houseNumber}")

max_limit = 999
print(f"the type of temperature is {type(temperature)} and value of temperature is {temperature}")

current_score = 44
print(f"the type of temperature is {type(temperature)} and value of temperature is {temperature}")

pen_count = 10
print(f"the type of temperature is {type(temperature)} and value of temperature is {temperature}")

bus_number = 17
print(f"the type of temperature is {type(temperature)} and value of temperature is {temperature}")

callsReceived = 90
print(f"the type of callsReceived is {type(callsReceived)} and value of callsReceived is {callsReceived}")

itemPrice = 349
print(f"the type of itemPrice is {type(itemPrice)} and value of itemPrice is {itemPrice}")

followers = 7000
print(f"the type of followers is {type(followers)} and value of followers is {followers}")

likesToday = 212
print(f"the type of likesToday is {type(likesToday)} and value of likesToday is {likesToday}")

daysInMonth = 31
print(f"the type of daysInMonth is {type(daysInMonth)} and value of daysInMonth is {daysInMonth}")

attempts = 2
print(f"the type of attempts is {type(attempts)} and value of attempts is {attempts}")

totalItems = 150
print(f"the type of totalItems is {type(totalItems)} and value of totalItems is {totalItems}")

inventoryCount = 900
print(f"the type of inventoryCount is {type(inventoryCount)} and value of inventoryCount is {inventoryCount}")

weekNumber = 52
print(f"the type of weekNumber is {type(weekNumber)} and value of weekNumber is {weekNumber}")

retryCount = 3
print(f"the type of retryCount is {type(retryCount)} and value of retryCount is {retryCount}")

studentsPassed = 87
print(f"the type of studentsPassed is {type(studentsPassed)} and value of studentsPassed is {studentsPassed}")

newUsers = 45
print(f"the type of newUsers is {type(newUsers)} and value of newUsers is {newUsers}")

visits = 91
print(f"the type of visits is {type(visits)} and value of visits is {visits}")

availableSeats = 140
print(f"the type of availableSeats is {type(availableSeats)} and value of availableSeats is {availableSeats}")

messagesSent = 65
print(f"the type of messagesSent is {type(messagesSent)} and value of messagesSent is {messagesSent}")

coinsCollected = 9999
print(f"the type of coinsCollected is {type(coinsCollected)} and value of coinsCollected is {coinsCollected}")

boxes = 8
print(f"the type of boxes is {type(boxes)} and value of boxes is {boxes}")

hoursStudied = 6
print(f"the type of hoursStudied is {type(hoursStudied)} and value of hoursStudied is {hoursStudied}")

stars = 5
print(f"the type of stars is {type(stars)} and value of stars is {stars}")

mistakesMade = 1
print(f"the type of mistakesMade is {type(mistakesMade)} and value of mistakesMade is {mistakesMade}")

trainNumber = 1400
print(f"the type of trainNumber is {type(trainNumber)} and value of trainNumber is {trainNumber}")
# Out:
# the type of year is <class 'int'> and the value of the year is 2024
# the type of temperature is <class 'int'> and value of temperature is -10
# the type of score is <class 'int'> and value of score is 100
# the type of quantity is <class 'int'> and value of quantity is 50
# the type of heightCm is <class 'int'> and value of heightCm is 175
# the type of weightKg is <class 'int'> and value of weightKg is 60
# the type of studentsCount is <class 'int'> and value of studentsCount is 30
# the type of buildings is <class 'int'> and value of buildings is 12
# the type of pagesRead is <class 'int'> and value of pagesRead is 120
# the type of marksMath is <class 'int'> and value of marksMath is 88
# the type of apples is <class 'int'> and value of apples is 4
# the type of oranges is <class 'int'> and value of oranges is 7
# the type of siblingCount is <class 'int'> and value of siblingCount is 2
# the type of distanceKm is <class 'int'> and value of distanceKm is 15
# ...

# %% [markdown]
# 2. Strings

# %%
firstName = "Twinkle"
print(f"the type of firstName is {type(firstName)} and value of firstName is {firstName}")

lastName = "Bawane"
print(f"the type of lastName is {type(lastName)} and value of lastName is {lastName}")

language = "Python"
print(f"the type of language is {type(language)} and value of language is {language}")

greeting = "hello"
print(f"the type of greeting is {type(greeting)} and value of greeting is {greeting}")

farewell = "bye"
print(f"the type of farewell is {type(farewell)} and value of farewell is {farewell}")

status = "active"
print(f"the type of status is {type(status)} and value of status is {status}")

color = "blue"
print(f"the type of color is {type(color)} and value of color is {color}")

mood = "happy"
print(f"the type of mood is {type(mood)} and value of mood is {mood}")

title = "developer"
print(f"the type of title is {type(title)} and value of title is {title}")

platform = "Internshala"
print(f"the type of platform is {type(platform)} and value of platform is {platform}")

course = "data analytics"
print(f"the type of course is {type(course)} and value of course is {course}")

city = "Mumbai"
print(f"the type of city is {type(city)} and value of city is {city}")

country = "India"
print(f"the type of country is {type(country)} and value of country is {country}")

emailProvider = "Gmail"
print(f"the type of emailProvider is {type(emailProvider)} and value of emailProvider is {emailProvider}")

fileType = "PDF"
print(f"the type of fileType is {type(fileType)} and value of fileType is {fileType}")

subject = "Math"
print(f"the type of subject is {type(subject)} and value of subject is {subject}")

fruit = "apple"
print(f"the type of fruit is {type(fruit)} and value of fruit is {fruit}")

pet = "dog"
print(f"the type of pet is {type(pet)} and value of pet is {pet}")

weather = "sunny"
print(f"the type of weather is {type(weather)} and value of weather is {weather}")

hobby = "reading"
print(f"the type of hobby is {type(hobby)} and value of hobby is {hobby}")

vehicle = "car"
print(f"the type of vehicle is {type(vehicle)} and value of vehicle is {vehicle}")

emotion = "joy"
print(f"the type of emotion is {type(emotion)} and value of emotion is {emotion}")

season = "summer"
print(f"the type of season is {type(season)} and value of season is {season}")

flower = "rose"
print(f"the type of flower is {type(flower)} and value of flower is {flower}")

language2 = "JavaScript"
print(f"the type of language2 is {type(language2)} and value of language2 is {language2}")

tool = "GitHub"
print(f"the type of tool is {type(tool)} and value of tool is {tool}")

food = "pizza"
print(f"the type of food is {type(food)} and value of food is {food}")

drink = "coffee"
print(f"the type of drink is {type(drink)} and value of drink is {drink}")

jobRole = "intern"
print(f"the type of jobRole is {type(jobRole)} and value of jobRole is {jobRole}")

university = "MIT"
print(f"the type of university is {type(university)} and value of university is {university}")

movieName = "Inception"
print(f"the type of movieName is {type(movieName)} and value of movieName is {movieName}")

series = "Friends"
print(f"the type of series is {type(series)} and value of series is {series}")

password = "secret123"
print(f"the type of password is {type(password)} and value of password is {password}")

phoneBrand = "Samsung"
print(f"the type of phoneBrand is {type(phoneBrand)} and value of phoneBrand is {phoneBrand}")

channel = "YouTube"
print(f"the type of channel is {type(channel)} and value of channel is {channel}")

browser = "Chrome"
print(f"the type of browser is {type(browser)} and value of browser is {browser}")

songTitle = "Imagine"
print(f"the type of songTitle is {type(songTitle)} and value of songTitle is {songTitle}")

artistName = "Adele"
print(f"the type of artistName is {type(artistName)} and value of artistName is {artistName}")

username = "twinkleb"
print(f"the type of username is {type(username)} and value of username is {username}")

passwordHint = "pet name"
print(f"the type of passwordHint is {type(passwordHint)} and value of passwordHint is {passwordHint}")

location = "library"
print(f"the type of location is {type(location)} and value of location is {location}")

station = "Andheri"
print(f"the type of station is {type(station)} and value of station is {station}")

sport = "cricket"
print(f"the type of sport is {type(sport)} and value of sport is {sport}")

bookName = "Atomic Habits"
print(f"the type of bookName is {type(bookName)} and value of bookName is {bookName}")

quote = "never give up"
print(f"the type of quote is {type(quote)} and value of quote is {quote}")

skill = "coding"
print(f"the type of skill is {type(skill)} and value of skill is {skill}")

emoji = "Smiley"
print(f"the type of emoji is {type(emoji)} and value of emoji is {emoji}")

answer = "maybe"
print(f"the type of answer is {type(answer)} and value of answer is {answer}")

gender = "female"
print(f"the type of gender is {type(gender)} and value of gender is {gender}")
# Out:
# the type of firstName is <class 'str'> and value of firstName is Twinkle
# the type of lastName is <class 'str'> and value of lastName is Bawane
# the type of language is <class 'str'> and value of language is Python
# the type of greeting is <class 'str'> and value of greeting is hello
# the type of farewell is <class 'str'> and value of farewell is bye
# the type of status is <class 'str'> and value of status is active
# the type of color is <class 'str'> and value of color is blue
# the type of mood is <class 'str'> and value of mood is happy
# the type of title is <class 'str'> and value of title is developer
# the type of platform is <class 'str'> and value of platform is Internshala
# the type of course is <class 'str'> and value of course is data analytics
# the type of city is <class 'str'> and value of city is Mumbai
# the type of country is <class 'str'> and value of country is India
# the type of emailProvider is <class 'str'> and value of emailProvider is Gmail
# ...

# %% [markdown]
# 3. Boolean

# %%
isLoggedIn = True
print(f"the type of isLoggedIn is {type(isLoggedIn)} and value of isLoggedIn is {isLoggedIn}")

isAdmin = False
print(f"the type of isAdmin is {type(isAdmin)} and value of isAdmin is {isAdmin}")

isVerified = True
print(f"the type of isVerified is {type(isVerified)} and value of isVerified is {isVerified}")

hasAccess = False
print(f"the type of hasAccess is {type(hasAccess)} and value of hasAccess is {hasAccess}")

isActive = True
print(f"the type of isActive is {type(isActive)} and value of isActive is {isActive}")

isAvailable = True
print(f"the type of isAvailable is {type(isAvailable)} and value of isAvailable is {isAvailable}")

isDeleted = False
print(f"the type of isDeleted is {type(isDeleted)} and value of isDeleted is {isDeleted}")

isFemale = True
print(f"the type of isFemale is {type(isFemale)} and value of isFemale is {isFemale}")

isMale = False
print(f"the type of isMale is {type(isMale)} and value of isMale is {isMale}")

hasSubscription = False
print(f"the type of hasSubscription is {type(hasSubscription)} and value of hasSubscription is {hasSubscription}")

emailVerified = True
print(f"the type of emailVerified is {type(emailVerified)} and value of emailVerified is {emailVerified}")

phoneVerified = False
print(f"the type of phoneVerified is {type(phoneVerified)} and value of phoneVerified is {phoneVerified}")

paymentDone = True
print(f"the type of paymentDone is {type(paymentDone)} and value of paymentDone is {paymentDone}")

paymentPending = False
print(f"the type of paymentPending is {type(paymentPending)} and value of paymentPending is {paymentPending}")

hasDiscount = True
print(f"the type of hasDiscount is {type(hasDiscount)} and value of hasDiscount is {hasDiscount}")

couponValid = False
print(f"the type of couponValid is {type(couponValid)} and value of couponValid is {couponValid}")

hasPassed = True
print(f"the type of hasPassed is {type(hasPassed)} and value of hasPassed is {hasPassed}")

isEligible = False
print(f"the type of isEligible is {type(isEligible)} and value of isEligible is {isEligible}")

isQualified = True
print(f"the type of isQualified is {type(isQualified)} and value of isQualified is {isQualified}")

registrationOpen = False
print(f"the type of registrationOpen is {type(registrationOpen)} and value of registrationOpen is {registrationOpen}")

accountLocked = True
print(f"the type of accountLocked is {type(accountLocked)} and value of accountLocked is {accountLocked}")

accountEnabled = True
print(f"the type of accountEnabled is {type(accountEnabled)} and value of accountEnabled is {accountEnabled}")

passwordExpired = False
print(f"the type of passwordExpired is {type(passwordExpired)} and value of passwordExpired is {passwordExpired}")

termsAccepted = True
print(f"the type of termsAccepted is {type(termsAccepted)} and value of termsAccepted is {termsAccepted}")

privacyChecked = False
print(f"the type of privacyChecked is {type(privacyChecked)} and value of privacyChecked is {privacyChecked}")

videoPlaying = True
print(f"the type of videoPlaying is {type(videoPlaying)} and value of videoPlaying is {videoPlaying}")

audioMuted = False
print(f"the type of audioMuted is {type(audioMuted)} and value of audioMuted is {audioMuted}")

wifiConnected = False
print(f"the type of wifiConnected is {type(wifiConnected)} and value of wifiConnected is {wifiConnected}")

bluetoothEnabled = True
print(f"the type of bluetoothEnabled is {type(bluetoothEnabled)} and value of bluetoothEnabled is {bluetoothEnabled}")

darkModeOn = True
print(f"the type of darkModeOn is {type(darkModeOn)} and value of darkModeOn is {darkModeOn}")

notificationEnabled = False
print(f"the type of notificationEnabled is {type(notificationEnabled)} and value of notificationEnabled is {notificationEnabled}")

taskCompleted = True
print(f"the type of taskCompleted is {type(taskCompleted)} and value of taskCompleted is {taskCompleted}")

dataSynced = True
print(f"the type of dataSynced is {type(dataSynced)} and value of dataSynced is {dataSynced}")

isUploaded = False
print(f"the type of isUploaded is {type(isUploaded)} and value of isUploaded is {isUploaded}")

backupDone = False
print(f"the type of backupDone is {type(backupDone)} and value of backupDone is {backupDone}")

maintenanceMode = True
print(f"the type of maintenanceMode is {type(maintenanceMode)} and value of maintenanceMode is {maintenanceMode}")

cameraOn = True
print(f"the type of cameraOn is {type(cameraOn)} and value of cameraOn is {cameraOn}")

micOn = True
print(f"the type of micOn is {type(micOn)} and value of micOn is {micOn}")

screenShared = False
print(f"the type of screenShared is {type(screenShared)} and value of screenShared is {screenShared}")

updateRequired = True
print(f"the type of updateRequired is {type(updateRequired)} and value of updateRequired is {updateRequired}")

hasProfilePic = False
print(f"the type of hasProfilePic is {type(hasProfilePic)} and value of hasProfilePic is {hasProfilePic}")

locationEnabled = False
print(f"the type of locationEnabled is {type(locationEnabled)} and value of locationEnabled is {locationEnabled}")

gpsAvailable = True
print(f"the type of gpsAvailable is {type(gpsAvailable)} and value of gpsAvailable is {gpsAvailable}")

permissionGranted = True
print(f"the type of permissionGranted is {type(permissionGranted)} and value of permissionGranted is {permissionGranted}")

requestSent = False
print(f"the type of requestSent is {type(requestSent)} and value of requestSent is {requestSent}")

timerRunning = True
print(f"the type of timerRunning is {type(timerRunning)} and value of timerRunning is {timerRunning}")

eventCompleted = False
print(f"the type of eventCompleted is {type(eventCompleted)} and value of eventCompleted is {eventCompleted}")

accessRevoked = True
print(f"the type of accessRevoked is {type(accessRevoked)} and value of accessRevoked is {accessRevoked}")

isLocked = False
print(f"the type of isLocked is {type(isLocked)} and value of isLocked is {isLocked}")
# Out:
# the type of isLoggedIn is <class 'bool'> and value of isLoggedIn is True
# the type of isAdmin is <class 'bool'> and value of isAdmin is False
# the type of isVerified is <class 'bool'> and value of isVerified is True
# the type of hasAccess is <class 'bool'> and value of hasAccess is False
# the type of isActive is <class 'bool'> and value of isActive is True
# the type of isAvailable is <class 'bool'> and value of isAvailable is True
# the type of isDeleted is <class 'bool'> and value of isDeleted is False
# the type of isFemale is <class 'bool'> and value of isFemale is True
# the type of isMale is <class 'bool'> and value of isMale is False
# the type of hasSubscription is <class 'bool'> and value of hasSubscription is False
# the type of emailVerified is <class 'bool'> and value of emailVerified is True
# the type of phoneVerified is <class 'bool'> and value of phoneVerified is False
# the type of paymentDone is <class 'bool'> and value of paymentDone is True
# ...

# %% [markdown]
# 4. Fractions

# %%
fraction1 = "1/2"
print(f"the type of fraction1 is {type(fraction1)} and value of fraction is {fraction1}")

fraction2 = "3/4"
print(f"the type of fraction2 is {type(fraction2)} and the value of fraction2 is {fraction2}")

fraction3 = "2/3"
print(f"the type of fraction3 is {type(fraction3)} and the value of fraction3 is {fraction3}")

fraction4 = "5/6"
print(f"the type of fraction4 is {type(fraction4)} and the value of fraction4 is {fraction4}")

fraction5 = "7/8"
print(f"the type of fraction5 is {type(fraction5)} and the value of fraction5 is {fraction5}")

fraction6 = "9/10"
print(f"the type of fraction6 is {type(fraction6)} and the value of fraction6 is {fraction6}")

fraction7 = "11/12"
print(f"the type of fraction7 is {type(fraction7)} and the value of fraction7 is {fraction7}")

fraction8 = "13/14"
print(f"the type of fraction8 is {type(fraction8)} and the value of fraction8 is {fraction8}")

fraction9 = "15/16"
print(f"the type of fraction9 is {type(fraction9)} and the value of fraction9 is {fraction9}")

fraction10 = "17/18"
print(f"the type of fraction10 is {type(fraction10)} and the value of fraction10 is {fraction10}")

fraction11 = "1/3"
print(f"the type of fraction11 is {type(fraction11)} and the value of fraction11 is {fraction11}")

fraction12 = "2/5"
print(f"the type of fraction12 is {type(fraction12)} and the value of fraction12 is {fraction12}")

fraction13 = "3/7"
print(f"the type of fraction13 is {type(fraction13)} and the value of fraction13 is {fraction13}")

fraction14 = "4/9"
print(f"the type of fraction14 is {type(fraction14)} and the value of fraction14 is {fraction14}")

fraction15 = "5/11"
print(f"the type of fraction15 is {type(fraction15)} and the value of fraction15 is {fraction15}")

fraction16 = "6/13"
print(f"the type of fraction16 is {type(fraction16)} and the value of fraction16 is {fraction16}")

fraction17 = "7/15"
print(f"the type of fraction17 is {type(fraction17)} and the value of fraction17 is {fraction17}")

fraction18 = "8/17"
print(f"the type of fraction18 is {type(fraction18)} and the value of fraction18 is {fraction18}")

fraction19 = "9/19"
print(f"the type of fraction19 is {type(fraction19)} and the value of fraction19 is {fraction19}")

fraction20 = "10/21"
print(f"the type of fraction20 is {type(fraction20)} and the value of fraction20 is {fraction20}")

fraction21 = "1/4"
print(f"the type of fraction21 is {type(fraction21)} and the value of fraction21 is {fraction21}")

fraction22 = "1/5"
print(f"the type of fraction22 is {type(fraction22)} and the value of fraction22 is {fraction22}")

fraction23 = "1/6"
print(f"the type of fraction23 is {type(fraction23)} and the value of fraction23 is {fraction23}")

fraction24 = "1/7"
print(f"the type of fraction24 is {type(fraction24)} and the value of fraction24 is {fraction24}")

fraction25 = "1/8"
print(f"the type of fraction25 is {type(fraction25)} and the value of fraction25 is {fraction25}")

fraction26 = "1/9"
print(f"the type of fraction26 is {type(fraction26)} and the value of fraction26 is {fraction26}")

fraction27 = "1/10"
print(f"the type of fraction27 is {type(fraction27)} and the value of fraction27 is {fraction27}")

fraction28 = "2/7"
print(f"the type of fraction28 is {type(fraction28)} and the value of fraction28 is {fraction28}")

fraction29 = "3/8"
print(f"the type of fraction29 is {type(fraction29)} and the value of fraction29 is {fraction29}")

fraction30 = "4/11"
print(f"the type of fraction30 is {type(fraction30)} and the value of fraction30 is {fraction30}")

fraction31 = "5/12"
print(f"the type of fraction31 is {type(fraction31)} and the value of fraction31 is {fraction31}")

fraction32 = "6/17"
print(f"the type of fraction32 is {type(fraction32)} and the value of fraction32 is {fraction32}")

fraction33 = "7/20"
print(f"the type of fraction33 is {type(fraction33)} and the value of fraction33 is {fraction33}")

fraction34 = "8/23"
print(f"the type of fraction34 is {type(fraction34)} and the value of fraction34 is {fraction34}")

fraction35 = "9/25"
print(f"the type of fraction35 is {type(fraction35)} and the value of fraction35 is {fraction35}")

fraction36 = "10/27"
print(f"the type of fraction36 is {type(fraction36)} and the value of fraction36 is {fraction36}")

fraction37 = "11/29"
print(f"the type of fraction37 is {type(fraction37)} and the value of fraction37 is {fraction37}")

fraction38 = "12/31"
print(f"the type of fraction38 is {type(fraction38)} and the value of fraction38 is {fraction38}")

fraction39 = "13/33"
print(f"the type of fraction39 is {type(fraction39)} and the value of fraction39 is {fraction39}")

fraction40 = "14/35"
print(f"the type of fraction40 is {type(fraction40)} and the value of fraction40 is {fraction40}")

fraction41 = "15/37"
print(f"the type of fraction41 is {type(fraction41)} and the value of fraction41 is {fraction41}")

fraction42 = "16/39"
print(f"the type of fraction42 is {type(fraction42)} and the value of fraction42 is {fraction42}")

fraction43 = "17/41"
print(f"the type of fraction43 is {type(fraction43)} and the value of fraction43 is {fraction43}")

fraction44 = "18/43"
print(f"the type of fraction44 is {type(fraction44)} and the value of fraction44 is {fraction44}")

fraction45 = "19/45"
print(f"the type of fraction45 is {type(fraction45)} and the value of fraction45 is {fraction45}")

fraction46 = "20/47"
print(f"the type of fraction46 is {type(fraction46)} and the value of fraction46 is {fraction46}")

fraction47 = "21/49"
print(f"the type of fraction47 is {type(fraction47)} and the value of fraction47 is {fraction47}")

fraction48 = "22/51"
print(f"the type of fraction48 is {type(fraction48)} and the value of fraction48 is {fraction48}")

fraction49 = "23/53"
print(f"the type of fraction49 is {type(fraction49)} and the value of fraction49 is {fraction49}")

fraction50 = "24/55"
print(f"the type of fraction50 is {type(fraction50)} and the value of fraction50 is {fraction50}")
# Out:
# the type of fraction1 is <class 'str'> and value of fraction is 1/2
# the type of fraction2 is <class 'str'> and the value of fraction2 is 3/4
# the type of fraction3 is <class 'str'> and the value of fraction3 is 2/3
# the type of fraction4 is <class 'str'> and the value of fraction4 is 5/6
# the type of fraction5 is <class 'str'> and the value of fraction5 is 7/8
# the type of fraction6 is <class 'str'> and the value of fraction6 is 9/10
# the type of fraction7 is <class 'str'> and the value of fraction7 is 11/12
# the type of fraction8 is <class 'str'> and the value of fraction8 is 13/14
# the type of fraction9 is <class 'str'> and the value of fraction9 is 15/16
# the type of fraction10 is <class 'str'> and the value of fraction10 is 17/18
# the type of fraction11 is <class 'str'> and the value of fraction11 is 1/3
# the type of fraction12 is <class 'str'> and the value of fraction12 is 2/5
# the type of fraction13 is <class 'str'> and the value of fraction13 is 3/7
# ...

# %% [markdown]
# 5. Float

# %%
piApprox = 3.
print(f"the type of piApprox is {type(piApprox)} and the value of piApprox is {piApprox}")

gravity = 9.81
print(f"the type of gravity is {type(gravity)} and the value of gravity is {gravity}")

temperatureToday = 27.5
print(f"the type of temperatureToday is {type(temperatureToday)} and the value of temperatureToday is {temperatureToday}")

bankBalance = 1024.75
print(f"the type of bankBalance is {type(bankBalance)} and the value of bankBalance is {bankBalance}")

averageSpeed = 60.5
print(f"the type of averageSpeed is {type(averageSpeed)} and the value of averageSpeed is {averageSpeed}")

discount = 15.99
print(f"the type of discount is {type(discount)} and the value of discount is {discount}")

heightMeters = 1.
print(f"the type of heightMeters is {type(heightMeters)} and the value of heightMeters is {heightMeters}")

exchangeRate = 83.25
print(f"the type of exchangeRate is {type(exchangeRate)} and the value of exchangeRate is {exchangeRate}")

rating = 4.5
print(f"the type of rating is {type(rating)} and the value of rating is {rating}")

taxRate = 18.0
print(f"the type of taxRate is {type(taxRate)} and the value of taxRate is {taxRate}")

interestRate = 7.
print(f"the type of interestRate is {type(interestRate)} and the value of interestRate is {interestRate}")

loanAmount = 50000.00
print(f"the type of loanAmount is {type(loanAmount)} and the value of loanAmount is {loanAmount}")

distanceTravelled = 120.75
print(f"the type of distanceTravelled is {type(distanceTravelled)} and the value of distanceTravelled is {distanceTravelled}")

weightLost = 3.2
print(f"the type of weightlost is {type(weightlost)} and the value of weightlost is {weightlost}")

humidity = 56.7
print(f"the type of humidity is {type(humidity)} and the value of humidity is {humidity}")

temperatureNight = 22.3
print(f"the type of temperatureNight is {type(temperatureNight)} and the value of temperatureNight is {temperatureNight}")

examScore = 92.1
print(f"the type of examScore is {type(examScore)} and the value of examScore is {examScore}")

percentage = 88.5
print(f"the type of percentage is {type(percentage)} and the value of percentage is {percentage}")

discountRate = 10.1
print(f"the type of discountRate is {type(discountRate)} and the value of discountRate is {discountRate}")

unitPrice = 49.99
print(f"the type of unitPrice is {type(unitPrice)} and the value of unitPrice is {unitPrice}")

totalWeight = 75.6
print(f"the type of totalWeight is {type(totalWeight)} and the value of totalWeight is {totalWeight}")

BMI = 21.2
print(f"the type of BMI is {type(BMI)} and the value of BMI is {BMI}")

areaSqft = 150.5
print(f"the type of areaSqft is {type(areaSqft)} and the value of areaSqft is {areaSqft}")

volume = 305.6
print(f"the type of volume is {type(volume)} and the value of volume is {volume}")

celsius = 37.5
print(f"the type of celsius is {type(celsius)} and the value of celsius is {celsius}")

fahrenheit = 98.6
print(f"the type of fahrenheit is {type(fahrenheit)} and the value of fahrenheit is {fahrenheit}")

speedometer = 79.9
print(f"the type of speedometer is {type(speedometer)} and the value of speedometer is {speedometer}")

batteryPercentage = 19.5
print(f"the type of batteryPercentage is {type(batteryPercentage)} and the value of batteryPercentage is {batteryPercentage}")

downloadSpeed = 3.85
print(f"the type of downlaodSpeed is {type(downlaodSpeed)} and the value of downlaodSpeed is {downlaodSpeed}")

uploadSpeed = 2.3
print(f"the type of uploadSpeed is {type(uploadSpeed)} and the value of uploadSpeed is {uploadSpeed}")

networkLatency = 0.05
print(f"the type of networkLatency is {type(networkLatency)} and the value of networkLatency is {networkLatency}")

probability = 0.95
print(f"the type of probability is {type(probability)} and the value of probability is {probability}")

scoreAvg = 33.
print(f"the type of scoreAvg is {type(scoreAvg)} and the value of scoreAvg is {scoreAvg}")

ratingOutOf5 = 4.3
print(f"the type of ratingOutOf5 is {type(ratingOutOf5)} and the value of ratingOutOf5 is {ratingOutOf5}")

amountDue = 300.99
print(f"the type of amountDue is {type(amountDue)} and the value of amountDue is {amountDue}")

travelTimeHr = 6.75
print(f"the type of travelTimeHr is {type(travelTimeHr)} and the value of travelTimeHr is {travelTimeHr}")

screenSize = 15.6
print(f"the type of screenSize is {type(screenSize)} and the value of screenSize is {screenSize}")

monthlyRent = 12345.89
print(f"the type of monthlyRent is {type(monthlyRent)} and the value of monthlyRent is {monthlyRent}")

exchangeDifference = -0.85
print(f"the type of exchangeDifference is {type(exchangeDifference)} and the value of exchangeDifference is {exchangeDifference}")

netProfit = 5000.75
print(f"the type of netProfit is {type(netProfit)} and the value of netProfit is {netProfit}")
# Out:
# the type of piApprox is <class 'float'> and the value of piApprox is 3.0
# the type of gravity is <class 'float'> and the value of gravity is 9.81
# the type of temperatureToday is <class 'float'> and the value of temperatureToday is 27.5
# the type of bankBalance is <class 'float'> and the value of bankBalance is 1024.75
# the type of averageSpeed is <class 'float'> and the value of averageSpeed is 60.5
# the type of discount is <class 'float'> and the value of discount is 15.99
# the type of heightMeters is <class 'float'> and the value of heightMeters is 1.0
# the type of exchangeRate is <class 'float'> and the value of exchangeRate is 83.25
# the type of rating is <class 'float'> and the value of rating is 4.5
# the type of taxRate is <class 'float'> and the value of taxRate is 18.0
# the type of interestRate is <class 'float'> and the value of interestRate is 7.0
# the type of loanAmount is <class 'float'> and the value of loanAmount is 50000.0
# ...

# %% [markdown]
# 6. List

# %%
l1 = [25, "Twinkle", True, 3.14, "1/2", [1, 2, 3], 404, "Python", False, 9.81, "2/3", ["apple", "banana"], 0, "Data", True, 1.23, "3/5", [True, False], -10, "Internshala", False, 0.99, "5/6", ["red", "blue", "green"], 88, "Login", True, 7.77, "4/7", ["x", "y"], 123, "Email", False, 2.5, "7/8", ["on", "off"], 999, "Submit", True, 6.28, "9/10", ["cat", "dog"], -404, "Success", False, 10.01, "11/12", ["pass", "fail"], 786]

print(f"type of l1 is {type(l1)} and value is '{l1}' ")
print(f"type of l1 [0] is {type(l1[0])} and value is '{l1[0]}' ")
print(f"type of l1 [1] is {type(l1[1])} and value is '{l1[1]}' ")
print(f"type of l1 [2] is {type(l1[2])} and value is '{l1[2]}' ") 
print(f"type of l1 [3] is {type(l1[3])} and value is '{l1[3]}' ")
print(f"type of l1 [4] is {type(l1[4])} and value is '{l1[4]}' ")
print(f"type of l1 [5] is {type(l1[5])} and value is '{l1[5]}' ")
print(f"type of l1 [6] is {type(l1[6])} and value is '{l1[6]}' ")
print(f"type of l1 [7] is {type(l1[7])} and value is '{l1[7]}' ") 
print(f"type of l1 [7][1] is {type(l1[7][1])} and value is '{l1[7][1]}' ")
print(f"type of l1 [7][2] is {type(l1[7][2])} and value is '{l1[7][2]}' ")
print(f"type of l1 [8] is {type(l1[8])} and value is '{l1[8]}' ")
print(f"type of l1 [9] is {type(l1[9])} and value is '{l1[9]}' ")
print(f"type of l1 [10] is {type(l1[10])} and value is '{l1[10]}' ")
print(f"type of l1 [11] is {type(l1[11])} and value is '{l1[11]}' ")
print(f"type of l1 [12] is {type(l1[12])} and value is '{l1[12]}' ")
print(f"type of l1 [13] is {type(l1[13])} and value is '{l1[13]}' ")
print(f"type of l1 [14] is {type(l1[14])} and value is '{l1[14]}' ")
print(f"type of l1 [15] is {type(l1[15])} and value is '{l1[15]}' ")
print(f"type of l1 [16] is {type(l1[16])} and value is '{l1[16]}' ")
print(f"type of l1 [17] is {type(l1[17])} and value is '{l1[17]}' ")
print(f"type of l1 [18] is {type(l1[18])} and value is '{l1[18]}' ")
print(f"type of l1 [19] is {type(l1[19])} and value is '{l1[19]}' ")
print(f"type of l1 [20] is {type(l1[20])} and value is '{l1[20]}' ")
print(f"type of l1 [21] is {type(l1[21])} and value is '{l1[21]}' ")
print(f"type of l1 [22] is {type(l1[22])} and value is '{l1[22]}' ")
print(f"type of l1 [23] is {type(l1[23])} and value is '{l1[23]}' ")
print(f"type of l1 [24] is {type(l1[24])} and value is '{l1[24]}' ")
print(f"type of l1 [25] is {type(l1[25])} and value is '{l1[25]}' ")
print(f"type of l1 [26] is {type(l1[26])} and value is '{l1[26]}' ")
print(f"type of l1 [27] is {type(l1[27])} and value is '{l1[27]}' ")
print(f"type of l1 [28] is {type(l1[28])} and value is '{l1[28]}' ")
print(f"type of l1 [29] is {type(l1[29])} and value is '{l1[29]}' ")
print(f"type of l1 [30] is {type(l1[30])} and value is '{l1[30]}' ")
print(f"type of l1 [31] is {type(l1[31])} and value is '{l1[31]}' ")
print(f"type of l1 [32] is {type(l1[32])} and value is '{l1[32]}' ")
print(f"type of l1 [33] is {type(l1[33])} and value is '{l1[33]}' ")
print(f"type of l1 [34] is {type(l1[34])} and value is '{l1[34]}' ")
print(f"type of l1 [35] is {type(l1[35])} and value is '{l1[35]}' ")
print(f"type of l1 [36] is {type(l1[36])} and value is '{l1[36]}' ")
print(f"type of l1 [37] is {type(l1[37])} and value is '{l1[37]}' ")
print(f"type of l1 [38] is {type(l1[38])} and value is '{l1[38]}' ")
print(f"type of l1 [39] is {type(l1[39])} and value is '{l1[39]}' ")
print(f"type of l1 [40] is {type(l1[40])} and value is '{l1[40]}' ")
print(f"type of l1 [41] is {type(l1[41])} and value is '{l1[41]}' ")
print(f"type of l1 [42] is {type(l1[42])} and value is '{l1[42]}' ")
print(f"type of l1 [43] is {type(l1[43])} and value is '{l1[43]}' ")
print(f"type of l1 [44] is {type(l1[44])} and value is '{l1[44]}' ")
print(f"type of l1 [45] is {type(l1[45])} and value is '{l1[45]}' ")
print(f"type of l1 [46] is {type(l1[46])} and value is '{l1[46]}' ")
print(f"type of l1 [47] is {type(l1[47])} and value is '{l1[47]}' ")
print(f"type of l1 [48] is {type(l1[48])} and value is '{l1[48]}' ")
# Out:
# type of l1 is <class 'list'> and value is '[25, 'Twinkle', True, 3.14, '1/2', [1, 2, 3], 404, 'Python', False, 9.81, '2/3', ['apple', 'banana'], 0, 'Data', True, 1.23, '3/5', [True, False], -10, 'Internshala', False, 0.99, '5/6', ['red', 'blue', 'green'], 88, 'Login', True, 7.77, '4/7', ['x', 'y'], 123, 'Email', False, 2.5, '7/8', ['on', 'off'], 999, 'Submit', True, 6.28, '9/10', ['cat', 'dog'], -404, 'Success', False, 10.01, '11/12', ['pass', 'fail'], 786]'
# type of l1 [0] is <class 'int'> and value is '25'
# type of l1 [1] is <class 'str'> and value is 'Twinkle'
# type of l1 [2] is <class 'bool'> and value is 'True'
# type of l1 [3] is <class 'float'> and value is '3.14'
# type of l1 [4] is <class 'str'> and value is '1/2'
# type of l1 [5] is <class 'list'> and value is '[1, 2, 3]'
# type of l1 [6] is <class 'int'> and value is '404'
# type of l1 [7] is <class 'str'> and value is 'Python'
# type of l1 [7][1] is <class 'str'> and value is 'y'
# ...
